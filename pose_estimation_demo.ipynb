# %% [markdown]
# # Pose Estimation Web Application Demo Screenshots:

# %% [markdown]
# ## Initial Menu - Model Selection and Image Loading:

# %% [markdown]
# ![Screenshot 2024-08-01 171504.png](data:image/png;base64,...)

# %% [markdown]
# ## Full View of App After Prediction:

# %% [markdown]
# ![Screenshot 2024-08-01 171628.png](data:image/png;base64,...)

# %% [markdown]
# ## Prediction Close-Up (including example image of predicted psoe for comparison):

# %% [markdown]
# ![Screenshot 2024-08-01 171710.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-01 171734.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-08-01 171754.png](data:image/png;base64,...)
